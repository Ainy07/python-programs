# %%
def show():
    print("show is running")
    def inner():
        print("inner is running")
    return inner
t=show()
t()
# Out:
# Running cells with 'Python 3.11.0' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/dell/AppData/Local/Programs/Python/Python311/python.exe -m pip install ipykernel -U --user --force-reinstall'
